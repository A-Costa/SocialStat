# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [10, 8]

# %%
df = pd.read_excel('complete_dataset.xlsx', names = ['Company', 'Post', 'Video1/Image0', 'Timestamp', 'Likes', 'Love',
       'Haha', 'Wow', 'Sad', 'Angry', '# comments', '# shares', 'Comment 1',
       'Likes of comment 1', 'Comment 2', 'Likes of comment 2', 'Post URL'])

# %%
# This selects and prints the LIKES for a given company (in this case Wendy's)


data = df[df['Company'] == 'Wendy\'s']['Likes']

# %%
df['Company'].unique()
# Out:
# array(['Burger King', "Hardee's", 'KFC', "McDonald's", 'Quiznos',
#        "Wendy's"], dtype=object)

# %%
l.values
# Out:
# array([ 792,  428,  930,  843,  657,  118,  375, 2308, 3413, 1903,  404,
#         618,  344, 4188, 1761,  188,  146, 5385, 9147, 1613,  499, 2050,
#         475,  572,  297,  357,  631,  519, 6371, 1812, 2695, 2199,  190,
#        2009, 2592,  433,  684, 8578,  225,  231,  385, 3032, 2603, 4114,
#        5213, 1135, 3441, 1468, 2205, 3301])

# %%
df['Company'].ipynb_checkpoints/unique()
# Out:
# array(['Burger King', "Hardee's", 'KFC', "McDonald's", 'Quiznos',
#        "Wendy's"], dtype=object)

# %%
data = []
labels = []
for company, likes in df.groupby('Company')['Likes']:
    data.append(likes)
    labels.append(company)
fig1, ax1 = plt.subplots()
#ax1.set_title('')
ax1.boxplot(data, labels=labels, showfliers=False, notch=True)
plt.show()

# %%
'''
spread = np.random.rand(50) * 100
center = np.ones(1) * -50
data = np.concatenate((spread, center))
'''

data = df[df['Company'] == 'Burger King']['Likes']

fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12775f390>,
#   <matplotlib.lines.Line2D at 0x12775f6d8>],
#  'caps': [<matplotlib.lines.Line2D at 0x12775fa20>,
#   <matplotlib.lines.Line2D at 0x12775fd68>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1276f5f28>],
#  'medians': [<matplotlib.lines.Line2D at 0x12775fe48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x127769438>],
#  'means': []}
